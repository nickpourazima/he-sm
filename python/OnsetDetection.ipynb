# %%
# %matplotlib inline
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display
import stanford_mir; stanford_mir.init()

# %%
x, sr = librosa.load(          '/Users/nickpourazima/GitHub/he-sm/AudioFiles/dynamic_swing_click_44.1_16bit_10sec_120-150bpm.wav'
)
print(x.shape, sr)
# Out:
# (236237,) 22050

# %%
plt.figure(figsize=(14, 10))
librosa.display.waveplot(x, sr)

# %%
onset_frames = librosa.onset.onset_detect(x, sr=sr)
print(onset_frames) # frame numbers of estimated onsets
# Out:
# [  6  12  20  30  37  47  55  65  72  82  90 101 110 130 152 173 194 214
#  234 244 252 271 292 297 313 334 339 354 372 382 390 400 407 417 425 435
#  443 454]

# %%
onset_times = librosa.frames_to_time(onset_frames)
print(onset_times)
# Out:
# [ 0.13931973  0.27863946  0.46439909  0.69659864  0.85913832  1.09133787
#   1.27709751  1.50929705  1.67183673  1.90403628  2.08979592  2.34521542
#   2.55419501  3.0185941   3.52943311  4.01705215  4.5046712   4.96907029
#   5.43346939  5.66566893  5.85142857  6.29260771  6.78022676  6.89632653
#   7.2678458   7.75546485  7.87156463  8.21986395  8.63782313  8.87002268
#   9.05578231  9.28798186  9.45052154  9.68272109  9.86848073 10.10068027
#  10.28643991 10.54185941]

# %%
S = librosa.stft(x)
logS = librosa.amplitude_to_db(abs(S))
plt.figure(figsize=(14, 5))
librosa.display.specshow(logS, sr=sr, x_axis='time', y_axis='log', cmap='Reds')
plt.vlines(onset_times, 0, 10000, color='#3333FF')

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)
plt.vlines(onset_times, -0.8, 0.79, color='r', alpha=0.8)
