# %%
from __future__ import division
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/nickpourazima/GitHub/he-sm/Completed Tests/Combo/Combo_Final_F2Mods.csv',parse_dates=True)
subSetUsers = ['367','591','824','410']
users = ['394','390','399','486','591','510','729','932','521','514','379','824','506','552','367','410']
testList = ['A1a1','A1a2','A1a3','A1a4','A1b1','A1b2','A1b3','A1b4','A2a1','A2a2','A2a3','A2a4','A2b1','A2b2','A2b3','A2b4',
       'A3a1','A3a2','A3a3','A3a4','A3b1','A3b2','A3b3','A3b4','A4a1','A4a2','A4a3','A4a4','A4b1','A4b2','A4b3','A4b4',
       'H1a1','H1a2','H1a3','H1a4','H1b1','H1b2','H1b3','H1b4','H2a1','H2a2','H2a3','H2a4','H2b1','H2b2','H2b3','H2b4']
hapticTests=['H1a1','H1a2','H1a3','H1a4','H1b1','H1b2','H1b3','H1b4','H2a1','H2a2','H2a3','H2a4','H2b1','H2b2','H2b3','H2b4']
audibleTests=['A1a1','A1a2','A1a3','A1a4','A1b1','A1b2','A1b3','A1b4','A2a1','A2a2','A2a3','A2a4','A2b1','A2b2','A2b3','A2b4',
       'A3a1','A3a2','A3a3','A3a4','A3b1','A3b2','A3b3','A3b4','A4a1','A4a2','A4a3','A4a4','A4b1','A4b2','A4b3','A4b4']
df = df[df.Test.isin(testList)]
df = df[df["User ID"].isin(users)]
df2 = df[df["User ID"].isin(subSetUsers)]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Asynchrony', 'Group', 'IOI', 'Instrument', 'Max',
#        'Mean Asynchrony', 'Min', 'Missed Taps', 'Phase Correction Response',
#        'Sanitized Asynchrony', 'Sanitized Mean Asynchrony',
#        'Sanitized Std Dev Asynchrony', 'Sanitized Tap Onset',
#        'Std Dev Asynchrony', 'Tap Onset', 'Test', 'True Onset', 'User ID',
#        'Latency Correction Factor', 'Latency Corrected Sanitized Asynchrony'],
#       dtype='object')

# %%
t = df[df.Test.isin(audibleTests)]
# new = df[df.Group.isin(["Amateur"])]
# new["Latency Corrected Sanitized Asynchrony"]=new["Latency Corrected Sanitized Asynchrony"].abs()
# sns.jointplot(x="IOI",y="Latency Corrected Sanitized Asynchrony",data=new,kind="reg",col="Group")
sns.pairplot(t, x_vars=["IOI"],y_vars=["Latency Corrected Sanitized Asynchrony","Missed Taps","Phase Correction Response"],kind="reg",hue="Group")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-8f820c8ce84a> in <module>()
#       3 # new["Latency Corrected Sanitized Asynchrony"]=new["Latency Corrected Sanitized Asynchrony"].abs()
#       4 # sns.jointplot(x="IOI",y="Latency Corrected Sanitized Asynchrony",data=new,kind="reg",col="Group")
# ----> 5 sns.pairplot(t, x_vars=["IOI"],y_vars=["Latency Corrected Sanitized Asynchrony","Missed Taps","Phase Correction Response"],kind="reg",hue="Group")
#
# /usr/local/lib/python3.6/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2039                     hue_order=hue_order, palette=palette,
#    2040                     diag_sharey=diag_sharey,
# -> 2041                     size=size, aspect=aspect, dropna=dropna, **grid_kws)
#    2042
#    2043     # Add the markers here as PairGrid has figured out how many levels of the
#
# /usr/local/lib/python3.6/site-packages/seaborn/axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, diag_sharey, size, aspect, despine, dropna)
#    1268         if despine:
#    1269             utils.despine(fig=fig)
# -> 1270         fig.tight_layout()
#    1271
#    1272     def map(self, func, **kwargs):
#
# /usr/local/lib/python3.6/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2274             self, self.axes, subplotspec_list, renderer,
#    2275             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
# -> 2276         self.subplots_adjust(**kwargs)
#    2277
#    2278     def align_xlabels(self, axs=None):
#
# /usr/local/lib/python3.6/site-packages/matplotlib/figure.py in subplots_adjust(self, *args, **kwargs)
#    2086
#    2087         """
# -> 2088         self.subplotpars.update(*args, **kwargs)
#    2089         for ax in self.axes:
#    2090             if not isinstance(ax, SubplotBase):
#
# /usr/local/lib/python3.6/site-packages/matplotlib/figure.py in update(self, left, bottom, right, top, wspace, hspace)
#     239             if self.left >= self.right:
#     240                 reset()
# --> 241                 raise ValueError('left cannot be >= right')
#     242
#     243             if self.bottom >= self.top:
#
# ValueError: left cannot be >= right
